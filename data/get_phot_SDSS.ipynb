# %% [markdown]
# # HowTo get SDSS photometrical data
#
# В этом туториале показано, как можно извлечь фотометрические данные Слоановского обзора неба (Sloan Digital Sky Survey - SDSS) с помощью сервиса [`SkyServer`](http://skyserver.sdss.org/dr15/en/home.aspx).

# %% [markdown]
# ## Импорт таблицы скоплений галактик
#
# Мы будем работать с данными по скоплениям галактик, которые построены по SDSS в работу [Saulder et al. 2016](https://ui.adsabs.harvard.edu/abs/2016A%26A...596A..14S/abstract). Эту таблицу удобно напрямую импортировать из
# астрономического "каталога каталогов" [`Vizier`](http://vizier.u-strasbg.fr/viz-bin/VizieR-2). Можно руками импортировать с [веба](http://vizier.u-strasbg.fr/viz-bin/VizieR-3?-source=J/A%2bA/596/A14/grlist_s&-out.max=50&-out.form=HTML%20Table&-out.add=_r&-out.add=_RAJ,_DEJ&-sort=_r&-oc.form=sexa), но мы для удобства воспользуемся аффилированой с `astropy` библиотекой `astroquery`, которая еще пригодится ниже. Импортируем ее и устанавливаем `ROW_LIMIT = -1`, чтобы `Vizier` мог отдать полную таблицу, по умолчанию он отдает первые 50 записей. В исходной таблице `grlist` приводятся 229893 строк, которые включают не только скопления и группы галактик, но и отдельные галактики, которые не были присовокуплены ни к одной из структур. Для дальнейшей работы нам понадобятся лишь хорошие скопления/группы, к которы были приписаны десятки скоплений. В таблице есть колонка `Ntot`, которая показывает число галактик в скоплении/группе. При запросе в `Vizier` сразу попросим его выдавать скопления с `Ntot > 70`, таких будет чуть больше 100. На последующих этапах проекта можно будет изменить этот порог.

# %%
from astroquery.vizier import Vizier
Vizier.ROW_LIMIT = -1
grplist = Vizier.query_constraints(catalog="J/A+A/596/A14/grlist_s", Ntot=">70")[0]
grplist
# Out:
# <Table masked=True length=107>
# iGrID    RAJ2000      DEJ2000        z      ...     DL      Ntot  Dist
#            deg          deg                 ...    Mpc
# int32    float64      float64     float64   ...  float64   int32 bytes1
# ------ ------------ ------------ ---------- ... ---------- ----- ------
#    211 195.72035217  -2.52054167  0.0840534 ...   370.3425    91      *
#   1195 170.83279419   1.02137434  0.0749820 ...   327.8531    73      *
#   4766 164.55435181   1.60687900  0.0405723 ...   172.3759    81      *
#   5742 181.11277771   1.89597118  0.0212014 ...    88.6502    82      *
#   7892 243.49198914  49.18959808  0.0576766 ...   248.5541    87      *
#  10476 184.42135620   3.65584564  0.0786997 ...   345.1888   134      *
#  11499 214.39805603   2.05321932  0.0550035 ...   236.5068   121      *
#  12324 168.46244812   2.48143363  0.0772917 ...   338.6106   125      *
#  13370 220.17848206   3.46542287  0.0284896 ...   119.8401   220      *
#    ...          ...          ...        ... ...        ...   ...    ...
# 161693  17.51319695  13.97814178  0.0586846 ...   253.1110    73      *
# 163829 223.63117981  18.64236259  0.0592502 ...   255.6711   107      *
# 169600 188.94107056  26.90888023  0.0248510 ...   104.2220    75      *
# 176164 223.23046875  16.70285797  0.0457432 ...   195.1798   179      *
# 176804 176.00897217  19.94982529  0.0233983 ...    98.0128   396      *
# 179559 195.94413757  19.27152252  0.0645461 ...   279.7602    76      *
# 180785 216.58274841  16.79726028  0.0539050 ...   231.5713   128      *
# 181726 190.32279968  18.57458496  0.0731350 ...   319.2804   126      *
# 183718 181.00613403  20.23231697  0.0248034 ...   104.0186   146      *
# 191838 258.11993408  64.06074524  0.0799037 ...   350.8261   174      *

# %% [markdown]
# ## Из влечение данных с помощью `SDSS SkyServer`
#
#
# В фотометрчиеской части обзора SDSS содержится информация об очень большом количестве объектов на небе ~0.5 млрд. Поэтому извлекать полный dataset и работать с ним не имеет смысла для нашей задачи. Нам всего лишь нужно извлечь некоторые данные для областей неба около исследуемых скоплений/групп. Причем, как видно из таблицы `grplist`, разные скопления/группы имеют разный угловой размер на небе (колонка `AngRad`).
#
# Есть несколько способов извлечь фотометрические данные доступные в обзоре SDSS (Table Access Protocol (TAP), [CasJobs](https://skyserver.sdss.org/casjobs/)). Все они заключаются в работе с составлением SQL (или ADQL - SQL для работы с TAP) запросов. Но оказывается достаточно сложно составиь такой запрос, где будут извлекаться данные для каждого скопления с разным угловым размером. Поэтому более простой способ оказался вопспользовать сервисом `SkyServer` и выполнить индивидуаьные запросы для каждого скопления. Пример запроса "чистых" (без больших инструментальных проблем) фотометрических данных приведен [тут](http://skyserver.sdss.org/dr15/en/help/docs/realquery.aspx#cleanGals). Потренироваться в написании различных SQL запросов можно в [SkyServer SQL Form](http://skyserver.sdss.org/dr15/en/tools/search/sql.aspx).
#
# Мы же напишем небольшой скрипт для выполнения запросов и сохранения результатов на диск в `csv` файлы для каждого скопления.
#
# ### Замечания
# - Некоторые скопления очень большие и чтобы запрос переварился нужно увеличить timeout до 10 минут, которого хватает для успешного завершения большинства запросов.
# - Иногда запрос валится и требуется повторно запустить эту ячейку. Запросы кэшируются, поэтому при повторном выполнение время исполнения запроса оказывается не репрезентативным.
# - Чтобы заведомо покрыть все скопления, данные извлекаются с области в `factor = 1.5` раз больше, чем размер скопления `angRad`.

# %%
import time
from astroquery.sdss import SDSS

# Some clusters are huge and long time is required to proccessed query,
# so let's increase default timeout from 1 minute to 5 min
SDSS.TIMEOUT = 600

factor = 1.5

for idx, grp in enumerate(grplist):
    query = (
"""
SELECT
    g.objid, g.ra, g.dec, g. dered_g, g. dered_r, err_g, err_r, petroRad_r, petroRadErr_r
FROM
    Galaxy AS g,
    dbo.fGetNearbyObjEq({},{},{}) AS n 
WHERE
    g.objID = n.objID
    AND ((g.flags_r & 0x10000000) != 0)
        -- detected in BINNED1
    AND ((g.flags_r & 0x8100000c00a0) = 0)
        -- not NOPROFILE, PEAKCENTER, NOTCHECKED, PSF_FLUX_INTERP, SATURATED,
        -- or BAD_COUNTS_ERROR.
        -- if you want to accept objects with interpolation problems for PSF mags,
        -- change this to: AND ((flags_r & 0x800a0) = 0)
    AND (((g.flags_r & 0x400000000000) = 0) or (g.psfmagerr_r <= 0.2))
        -- not DEBLEND_NOPEAK or small PSF error
        -- (substitute psfmagerr in other band as appropriate)
    AND (((g.flags_r & 0x100000000000) = 0) or (g.flags_r & 0x1000) = 0)
        -- not INTERP_CENTER or not COSMIC_RAY - omit this AND clause if you want to
        -- accept objects with interpolation problems for PSF mags.
""".format(grp['RAJ2000'], grp['DEJ2000'], grp['angRad']*60.0*factor)
    )
    
    msg = "[{:d}/{:d}] Working on iGrID = {:<8d} (Ntot = {:<3d} Rad = {:<0.1f} arcmin) at RA={}; DEC={}"
    print(msg.format(idx+1, len(grplist), grp['iGrID'], grp['Ntot'],
                     grp['RAJ2000'], grp['DEJ2000'], grp['angRad']))
    
    # make query
    tstart = time.process_time()
    tbl = SDSS.query_sql(query, data_release=15)
    
    # save table to csv file 
    ofile = "phot_sdss_grps/phot_gals_irgp_{}.csv".format(grp['iGrID'])
    tbl.write(ofile, format="ascii.csv", overwrite=True)
    print("    Extracted {} galaxies in {:.1f} sec, saved to {}".format(len(tbl), time.process_time() - tstart, ofile))
# Out:
# [1/107] Working on iGrID = 211      (Ntot = 91  Rad = 195.7 arcmin) at RA=-2.52054167; DEC=0.184561
#     Extracted 2478 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_211.csv
# [2/107] Working on iGrID = 1195     (Ntot = 73  Rad = 170.8 arcmin) at RA=1.02137434; DEC=0.205672
#     Extracted 3549 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_1195.csv
# [3/107] Working on iGrID = 4766     (Ntot = 81  Rad = 164.6 arcmin) at RA=1.606879; DEC=0.28127
#     Extracted 4624 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_4766.csv
# [4/107] Working on iGrID = 5742     (Ntot = 82  Rad = 181.1 arcmin) at RA=1.89597118; DEC=0.297936
#     Extracted 6317 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_5742.csv
# [5/107] Working on iGrID = 7892     (Ntot = 87  Rad = 243.5 arcmin) at RA=49.18959808; DEC=0.300066
#     Extracted 7719 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_7892.csv
# [6/107] Working on iGrID = 10476    (Ntot = 134 Rad = 184.4 arcmin) at RA=3.65584564; DEC=0.185565
#     Extracted 2638 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_10476.csv
# [7/107] Working on iGrID = 11499    (Ntot = 121 Rad = 214.4 arcmin) at RA=2.05321932; DEC=0.308821
#     Extracted 8831 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_11499.csv
# [8/107] Working on iGrID = 12324    (Ntot = 125 Rad = 168.5 arcmin) at RA=2.48143363; DEC=0.312153
#     Extracted 7406 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_12324.csv
# [9/107] Working on iGrID = 13370    (Ntot = 220 Rad = 220.2 arcmin) at RA=3.46542287; DEC=0.61668
#     Extracted 28502 galaxies in 1.1 sec, saved to phot_sdss_grps/phot_gals_irgp_13370.csv
# [10/107] Working on iGrID = 13898    (Ntot = 100 Rad = 257.4 arcmin) at RA=34.40709686; DEC=0.155411
#     Extracted 2478 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_13898.csv
# [11/107] Working on iGrID = 16435    (Ntot = 162 Rad = 229.8 arcmin) at RA=4.52067566; DEC=0.793575
#     Extracted 50380 galaxies in 1.9 sec, saved to phot_sdss_grps/phot_gals_irgp_16435.csv
# [12/107] Working on iGrID = 17434    (Ntot = 84  Rad = 205.5 arcmin) at RA=2.22723579; DEC=0.177358
#     Extracted 2929 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_17434.csv
# [13/107] Working on iGrID = 18926    (Ntot = 95  Rad = 228.8 arcmin) at RA=4.39696884; DEC=0.181455
#     Extracted 3297 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_18926.csv
# [14/107] Working on iGrID = 19811    (Ntot = 120 Rad = 329.3 arcmin) at RA=-7.83959532; DEC=0.248148
#     Extracted 4931 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_19811.csv
# [15/107] Working on iGrID = 19966    (Ntot = 142 Rad = 358.6 arcmin) at RA=-10.41902161; DEC=0.21088
#     Extracted 3183 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_19966.csv
# [16/107] Working on iGrID = 20001    (Ntot = 96  Rad = 14.0 arcmin) at RA=-9.9856472; DEC=0.238697
#     Extracted 3919 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_20001.csv
# [17/107] Working on iGrID = 20078    (Ntot = 187 Rad = 10.4 arcmin) at RA=-9.23519897; DEC=0.311447
#     Extracted 7517 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_20078.csv
# [18/107] Working on iGrID = 20266    (Ntot = 214 Rad = 351.1 arcmin) at RA=14.64713192; DEC=0.384749
#     Extracted 11914 galaxies in 0.4 sec, saved to phot_sdss_grps/phot_gals_irgp_20266.csv
# [19/107] Working on iGrID = 20708    (Ntot = 75  Rad = 333.7 arcmin) at RA=13.84650898; DEC=0.330306
#     Extracted 8390 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_20708.csv
# [20/107] Working on iGrID = 29465    (Ntot = 78  Rad = 146.7 arcmin) at RA=54.4269371; DEC=0.268285
#     Extracted 5168 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_29465.csv
# [21/107] Working on iGrID = 29752    (Ntot = 81  Rad = 159.8 arcmin) at RA=5.20977736; DEC=0.143722
#     Extracted 2173 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_29752.csv
# [22/107] Working on iGrID = 29982    (Ntot = 87  Rad = 184.8 arcmin) at RA=5.27037048; DEC=0.252118
#     Extracted 4620 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_29982.csv
# [23/107] Working on iGrID = 30251    (Ntot = 82  Rad = 179.4 arcmin) at RA=5.08905125; DEC=0.183982
#     Extracted 3355 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_30251.csv
# [24/107] Working on iGrID = 30885    (Ntot = 252 Rad = 184.8 arcmin) at RA=6.09867811; DEC=2.669756
#     Extracted 500000 galaxies in 19.8 sec, saved to phot_sdss_grps/phot_gals_irgp_30885.csv
# [25/107] Working on iGrID = 32731    (Ntot = 102 Rad = 208.3 arcmin) at RA=5.14973068; DEC=0.141158
#     Extracted 1881 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_32731.csv
# [26/107] Working on iGrID = 34155    (Ntot = 103 Rad = 204.0 arcmin) at RA=59.23340225; DEC=0.154955
#     Extracted 2292 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_34155.csv
# [27/107] Working on iGrID = 36256    (Ntot = 90  Rad = 255.7 arcmin) at RA=34.06114578; DEC=0.124342
#     Extracted 1895 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_36256.csv
# [28/107] Working on iGrID = 39456    (Ntot = 567 Rad = 247.4 arcmin) at RA=40.81161118; DEC=1.055808
#     Extracted 92440 galaxies in 3.6 sec, saved to phot_sdss_grps/phot_gals_irgp_39456.csv
# [29/107] Working on iGrID = 40250    (Ntot = 145 Rad = 202.8 arcmin) at RA=-1.73027194; DEC=0.282986
#     Extracted 7315 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_40250.csv
# [30/107] Working on iGrID = 42643    (Ntot = 277 Rad = 227.8 arcmin) at RA=5.3172822; DEC=0.519213
#     Extracted 23462 galaxies in 0.9 sec, saved to phot_sdss_grps/phot_gals_irgp_42643.csv
# [31/107] Working on iGrID = 45917    (Ntot = 137 Rad = 229.2 arcmin) at RA=7.0216217; DEC=0.319636
#     Extracted 8751 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_45917.csv
# [32/107] Working on iGrID = 49458    (Ntot = 97  Rad = 117.5 arcmin) at RA=29.42019463; DEC=0.509069
#     Extracted 18149 galaxies in 0.7 sec, saved to phot_sdss_grps/phot_gals_irgp_49458.csv
# [33/107] Working on iGrID = 49580    (Ntot = 74  Rad = 4.2 arcmin) at RA=-0.44543657; DEC=0.372488
#     Extracted 11921 galaxies in 0.5 sec, saved to phot_sdss_grps/phot_gals_irgp_49580.csv
# [34/107] Working on iGrID = 49589    (Ntot = 97  Rad = 163.5 arcmin) at RA=54.82738113; DEC=0.213392
#     Extracted 3931 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_49589.csv
# [35/107] Working on iGrID = 50715    (Ntot = 92  Rad = 168.8 arcmin) at RA=54.44412231; DEC=0.213793
#     Extracted 4139 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_50715.csv
# [36/107] Working on iGrID = 50913    (Ntot = 96  Rad = 176.8 arcmin) at RA=55.73017883; DEC=0.17796
#     Extracted 2532 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_50913.csv
# [37/107] Working on iGrID = 51050    (Ntot = 85  Rad = 7.3 arcmin) at RA=-0.16377918; DEC=0.17528
#     Extracted 3387 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_51050.csv
# [38/107] Working on iGrID = 51154    (Ntot = 86  Rad = 177.0 arcmin) at RA=54.6462822; DEC=0.189712
#     Extracted 2820 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_51154.csv
# [39/107] Working on iGrID = 51429    (Ntot = 79  Rad = 122.5 arcmin) at RA=35.27526474; DEC=0.238328
#     Extracted 4940 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_51429.csv
# [40/107] Working on iGrID = 52238    (Ntot = 93  Rad = 180.1 arcmin) at RA=56.28614426; DEC=0.215087
#     Extracted 3705 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_52238.csv
# [41/107] Working on iGrID = 52380    (Ntot = 89  Rad = 173.1 arcmin) at RA=55.96744156; DEC=0.178818
#     Extracted 2434 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_52380.csv
# [42/107] Working on iGrID = 53587    (Ntot = 76  Rad = 134.6 arcmin) at RA=38.49320221; DEC=0.186531
#     Extracted 3319 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_53587.csv
# [43/107] Working on iGrID = 58065    (Ntot = 83  Rad = 146.5 arcmin) at RA=43.04671478; DEC=0.258522
#     Extracted 5589 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_58065.csv
# [44/107] Working on iGrID = 58282    (Ntot = 107 Rad = 173.7 arcmin) at RA=49.07763672; DEC=0.241197
#     Extracted 4987 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_58282.csv
# [45/107] Working on iGrID = 58643    (Ntot = 72  Rad = 207.9 arcmin) at RA=46.36671448; DEC=0.19702
#     Extracted 3377 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_58643.csv
# [46/107] Working on iGrID = 62024    (Ntot = 93  Rad = 127.1 arcmin) at RA=30.43132019; DEC=0.146149
#     Extracted 1551 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_62024.csv
# [47/107] Working on iGrID = 64669    (Ntot = 87  Rad = 175.7 arcmin) at RA=8.16227913; DEC=0.35827
#     Extracted 11467 galaxies in 0.5 sec, saved to phot_sdss_grps/phot_gals_irgp_64669.csv
# [48/107] Working on iGrID = 65627    (Ntot = 110 Rad = 186.9 arcmin) at RA=8.82488155; DEC=0.180053
#     Extracted 2847 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_65627.csv
# [49/107] Working on iGrID = 67012    (Ntot = 74  Rad = 192.2 arcmin) at RA=55.06230927; DEC=0.255378
#     Extracted 5563 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_67012.csv
# [50/107] Working on iGrID = 67252    (Ntot = 99  Rad = 187.5 arcmin) at RA=11.67745399; DEC=0.203813
#     Extracted 3684 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_67252.csv
# [51/107] Working on iGrID = 70533    (Ntot = 114 Rad = 244.4 arcmin) at RA=35.00421524; DEC=0.326565
#     Extracted 8658 galaxies in 0.4 sec, saved to phot_sdss_grps/phot_gals_irgp_70533.csv
# [52/107] Working on iGrID = 80308    (Ntot = 103 Rad = 139.9 arcmin) at RA=33.62400436; DEC=0.428915
#     Extracted 14723 galaxies in 0.6 sec, saved to phot_sdss_grps/phot_gals_irgp_80308.csv
# [53/107] Working on iGrID = 81481    (Ntot = 154 Rad = 173.2 arcmin) at RA=14.46117496; DEC=0.35207
#     Extracted 10843 galaxies in 0.4 sec, saved to phot_sdss_grps/phot_gals_irgp_81481.csv
# [54/107] Working on iGrID = 81704    (Ntot = 80  Rad = 129.8 arcmin) at RA=28.84410858; DEC=0.298312
#     Extracted 6554 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_81704.csv
# [55/107] Working on iGrID = 82182    (Ntot = 141 Rad = 49.2 arcmin) at RA=41.32489777; DEC=0.701477
#     Extracted 33880 galaxies in 1.3 sec, saved to phot_sdss_grps/phot_gals_irgp_82182.csv
# [56/107] Working on iGrID = 83761    (Ntot = 109 Rad = 117.0 arcmin) at RA=18.5539341; DEC=0.265674
#     Extracted 5456 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_83761.csv
# [57/107] Working on iGrID = 85376    (Ntot = 72  Rad = 124.7 arcmin) at RA=22.95805931; DEC=0.344942
#     Extracted 10498 galaxies in 0.4 sec, saved to phot_sdss_grps/phot_gals_irgp_85376.csv
# [58/107] Working on iGrID = 87193    (Ntot = 92  Rad = 158.1 arcmin) at RA=40.27124405; DEC=0.123994
#     Extracted 1828 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_87193.csv
# [59/107] Working on iGrID = 92518    (Ntot = 80  Rad = 245.2 arcmin) at RA=29.81751633; DEC=0.194132
#     Extracted 3433 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_92518.csv
# [60/107] Working on iGrID = 95347    (Ntot = 80  Rad = 167.0 arcmin) at RA=43.91661835; DEC=0.207788
#     Extracted 3740 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_95347.csv
# [61/107] Working on iGrID = 95500    (Ntot = 93  Rad = 236.2 arcmin) at RA=36.10945511; DEC=0.154205
#     Extracted 2570 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_95500.csv
# [62/107] Working on iGrID = 95571    (Ntot = 72  Rad = 202.4 arcmin) at RA=11.74587822; DEC=0.396607
#     Extracted 12577 galaxies in 0.5 sec, saved to phot_sdss_grps/phot_gals_irgp_95571.csv
# [63/107] Working on iGrID = 98438    (Ntot = 119 Rad = 230.8 arcmin) at RA=8.60921764; DEC=0.223264
#     Extracted 4413 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_98438.csv
# [64/107] Working on iGrID = 101211   (Ntot = 156 Rad = 215.5 arcmin) at RA=48.57073975; DEC=0.27767
#     Extracted 7855 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_101211.csv
# [65/107] Working on iGrID = 101773   (Ntot = 181 Rad = 167.9 arcmin) at RA=40.820755; DEC=0.329344
#     Extracted 8066 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_101773.csv
# [66/107] Working on iGrID = 106224   (Ntot = 91  Rad = 230.5 arcmin) at RA=7.70881557; DEC=0.278485
#     Extracted 6378 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_106224.csv
# [67/107] Working on iGrID = 107210   (Ntot = 112 Rad = 231.9 arcmin) at RA=28.70054245; DEC=0.278694
#     Extracted 7572 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_107210.csv
# [68/107] Working on iGrID = 107331   (Ntot = 149 Rad = 228.2 arcmin) at RA=7.43439913; DEC=0.359623
#     Extracted 11283 galaxies in 0.5 sec, saved to phot_sdss_grps/phot_gals_irgp_107331.csv
# [69/107] Working on iGrID = 107404   (Ntot = 80  Rad = 225.9 arcmin) at RA=7.76059103; DEC=0.263327
#     Extracted 6975 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_107404.csv
# [70/107] Working on iGrID = 108889   (Ntot = 102 Rad = 239.9 arcmin) at RA=26.49953079; DEC=0.277539
#     Extracted 7763 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_108889.csv
# [71/107] Working on iGrID = 109343   (Ntot = 75  Rad = 197.8 arcmin) at RA=39.22685623; DEC=0.145152
#     Extracted 2312 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_109343.csv
# [72/107] Working on iGrID = 109739   (Ntot = 85  Rad = 214.4 arcmin) at RA=8.17959023; DEC=0.174952
#     Extracted 3137 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_109739.csv
# [73/107] Working on iGrID = 110698   (Ntot = 100 Rad = 238.0 arcmin) at RA=27.86658096; DEC=0.371808
#     Extracted 13336 galaxies in 0.5 sec, saved to phot_sdss_grps/phot_gals_irgp_110698.csv
# [74/107] Working on iGrID = 110724   (Ntot = 112 Rad = 230.3 arcmin) at RA=30.67093277; DEC=0.140582
#     Extracted 2126 galaxies in 0.1 sec, saved to phot_sdss_grps/phot_gals_irgp_110724.csv
# [75/107] Working on iGrID = 110860   (Ntot = 71  Rad = 210.7 arcmin) at RA=9.34137535; DEC=0.395333
#     Extracted 12509 galaxies in 0.5 sec, saved to phot_sdss_grps/phot_gals_irgp_110860.csv
# [76/107] Working on iGrID = 110973   (Ntot = 80  Rad = 208.0 arcmin) at RA=9.53128242; DEC=0.28377
#     Extracted 6998 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_110973.csv
# [77/107] Working on iGrID = 112271   (Ntot = 250 Rad = 239.6 arcmin) at RA=27.23340988; DEC=0.240063
#     Extracted 6237 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_112271.csv
# [78/107] Working on iGrID = 116091   (Ntot = 77  Rad = 239.5 arcmin) at RA=28.79562759; DEC=0.252447
#     Extracted 5759 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_116091.csv
# [79/107] Working on iGrID = 118434   (Ntot = 71  Rad = 233.3 arcmin) at RA=31.14516068; DEC=0.248367
#     Extracted 5766 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_118434.csv
# [80/107] Working on iGrID = 125949   (Ntot = 80  Rad = 226.0 arcmin) at RA=28.51953506; DEC=0.238141
#     Extracted 5522 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_125949.csv
# [81/107] Working on iGrID = 126645   (Ntot = 169 Rad = 230.6 arcmin) at RA=27.71437073; DEC=0.216069
#     Extracted 5549 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_126645.csv
# [82/107] Working on iGrID = 127065   (Ntot = 227 Rad = 14.1 arcmin) at RA=-1.25536931; DEC=0.574215
#     Extracted 30590 galaxies in 1.2 sec, saved to phot_sdss_grps/phot_gals_irgp_127065.csv
# [83/107] Working on iGrID = 127066   (Ntot = 170 Rad = 18.8 arcmin) at RA=0.21345596; DEC=0.27205
#     Extracted 7045 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_127066.csv
# [84/107] Working on iGrID = 132580   (Ntot = 91  Rad = 123.9 arcmin) at RA=58.32099152; DEC=0.333132
#     Extracted 8033 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_132580.csv
# [85/107] Working on iGrID = 139785   (Ntot = 89  Rad = 203.6 arcmin) at RA=34.77776718; DEC=0.692662
#     Extracted 42591 galaxies in 1.7 sec, saved to phot_sdss_grps/phot_gals_irgp_139785.csv
# [86/107] Working on iGrID = 143334   (Ntot = 96  Rad = 176.1 arcmin) at RA=33.51450729; DEC=0.472118
#     Extracted 18003 galaxies in 0.7 sec, saved to phot_sdss_grps/phot_gals_irgp_143334.csv
# [87/107] Working on iGrID = 146969   (Ntot = 73  Rad = 126.0 arcmin) at RA=19.41219902; DEC=0.194579
#     Extracted 3034 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_146969.csv
# [88/107] Working on iGrID = 149469   (Ntot = 113 Rad = 207.1 arcmin) at RA=26.41079712; DEC=0.307086
#     Extracted 8360 galaxies in 0.4 sec, saved to phot_sdss_grps/phot_gals_irgp_149469.csv
# [89/107] Working on iGrID = 149473   (Ntot = 896 Rad = 240.6 arcmin) at RA=16.34599113; DEC=0.942822
#     Extracted 82263 galaxies in 3.2 sec, saved to phot_sdss_grps/phot_gals_irgp_149473.csv
# [90/107] Working on iGrID = 150207   (Ntot = 143 Rad = 229.9 arcmin) at RA=20.89632034; DEC=0.618485
#     Extracted 33293 galaxies in 1.3 sec, saved to phot_sdss_grps/phot_gals_irgp_150207.csv
# [91/107] Working on iGrID = 152483   (Ntot = 140 Rad = 234.9 arcmin) at RA=21.78271484; DEC=0.285113
#     Extracted 6898 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_152483.csv
# [92/107] Working on iGrID = 153084   (Ntot = 765 Rad = 195.0 arcmin) at RA=27.97694016; DEC=0.717534
#     Extracted 44686 galaxies in 2.0 sec, saved to phot_sdss_grps/phot_gals_irgp_153084.csv
# [93/107] Working on iGrID = 153748   (Ntot = 75  Rad = 219.4 arcmin) at RA=24.85753822; DEC=0.280763
#     Extracted 6569 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_153748.csv
# [94/107] Working on iGrID = 154382   (Ntot = 73  Rad = 205.5 arcmin) at RA=26.36062431; DEC=0.182079
#     Extracted 3096 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_154382.csv
# [95/107] Working on iGrID = 159332   (Ntot = 118 Rad = 169.1 arcmin) at RA=29.25476646; DEC=0.274466
#     Extracted 6054 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_159332.csv
# [96/107] Working on iGrID = 159817   (Ntot = 75  Rad = 18.2 arcmin) at RA=15.49130726; DEC=0.197505
#     Extracted 3135 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_159817.csv
# [97/107] Working on iGrID = 160410   (Ntot = 229 Rad = 167.7 arcmin) at RA=28.76888657; DEC=0.498024
#     Extracted 19932 galaxies in 0.8 sec, saved to phot_sdss_grps/phot_gals_irgp_160410.csv
# [98/107] Working on iGrID = 161693   (Ntot = 73  Rad = 17.5 arcmin) at RA=13.97814178; DEC=0.266071
#     Extracted 7217 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_161693.csv
# [99/107] Working on iGrID = 163829   (Ntot = 107 Rad = 223.6 arcmin) at RA=18.64236259; DEC=0.239377
#     Extracted 5868 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_163829.csv
# [100/107] Working on iGrID = 169600   (Ntot = 75  Rad = 188.9 arcmin) at RA=26.90888023; DEC=0.430297
#     Extracted 16245 galaxies in 0.6 sec, saved to phot_sdss_grps/phot_gals_irgp_169600.csv
# [101/107] Working on iGrID = 176164   (Ntot = 179 Rad = 223.2 arcmin) at RA=16.70285797; DEC=0.334553
#     Extracted 10704 galaxies in 0.5 sec, saved to phot_sdss_grps/phot_gals_irgp_176164.csv
# [102/107] Working on iGrID = 176804   (Ntot = 396 Rad = 176.0 arcmin) at RA=19.94982529; DEC=0.779001
#     Extracted 51133 galaxies in 2.0 sec, saved to phot_sdss_grps/phot_gals_irgp_176804.csv
# [103/107] Working on iGrID = 179559   (Ntot = 76  Rad = 195.9 arcmin) at RA=19.27152252; DEC=0.183084
#     Extracted 3404 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_179559.csv
# [104/107] Working on iGrID = 180785   (Ntot = 128 Rad = 216.6 arcmin) at RA=16.79726028; DEC=0.301487
#     Extracted 7372 galaxies in 0.3 sec, saved to phot_sdss_grps/phot_gals_irgp_180785.csv
# [105/107] Working on iGrID = 181726   (Ntot = 126 Rad = 190.3 arcmin) at RA=18.57458496; DEC=0.210947
#     Extracted 4326 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_181726.csv
# [106/107] Working on iGrID = 183718   (Ntot = 146 Rad = 181.0 arcmin) at RA=20.23231697; DEC=0.448961
#     Extracted 18513 galaxies in 0.8 sec, saved to phot_sdss_grps/phot_gals_irgp_183718.csv
# [107/107] Working on iGrID = 191838   (Ntot = 174 Rad = 258.1 arcmin) at RA=64.06074524; DEC=0.171401
#     Extracted 3389 galaxies in 0.2 sec, saved to phot_sdss_grps/phot_gals_irgp_191838.csv

# %% [markdown]
# Полный размер сохраненных csv файлов составляет чуть менее 200mb:
# ```
# ik52@kaluga # data/phot_sdss_grps [master ✗] [12:53:43]
# ➜ du -h
# 189M
# ```
#
# ### Что имеем в извлеченных данных?
#
# В выполненных SQL запросах мы извлекали данные о галактиках (используются вьюха `Galaxy`) и попросили вернуть сервер следующие параметры:
# - `objid` - стандартный ID SDSS объекта
# - `ra`, `dec` - экваториальные небесные координаты
# - `dered_g`, `dered_r`, `err_g`, `err_r` - это звездные величины в фильтрах `g` и `r` и их ошибки. `dered_` означает, что эти величины были исправлены за поглащение света в Нашей Галактике. Разность `dered_g - dered_r` - это оптический цвет галактики. Если одинаковую галактику помещать на разное красное смещение, цвет галактики будет изменяться из-за космологического расширения, которое на больших масштабах уже будет заметно. Напомню, что звездная величина - это $-2.5\log (F) + Z_{point}$, где $F$ - это полный поток излучения, приходящий от галактики в данном фильтре, $Z_{point}$ - нуль-пункт.
# - `petroRad_R` и `petroRadErr_r` - [петросяновский радиус (Petrosian radius)](http://skyserver.sdss.org/dr7/en/help/docs/algorithm.asp?key=mag_petro) и ошибка в фильре `r`. Такой радиус является модельно незасимым и его можно сипользовать как индикатор размера галактики.

# %%
tbl
# Out:
# <Table length=2140>
#        objid               ra        ... petroRad_r petroRadErr_r
#        int64            float64      ...  float64      float64
# ------------------- ---------------- ... ---------- -------------
# 1237651752929722799 164.314764778059 ...   1.851976       1.67056
# 1237651752929722798 164.312940162349 ...    3.00205     0.3384922
# 1237651752929722796 164.311497433452 ...   2.577923     0.6609415
# 1237651752929722786 164.306495034618 ...   2.059687      0.234718
# 1237651752929722782 164.305636773052 ...   1.461135      0.142469
# 1237651752929722780 164.305343728178 ...   1.290057      0.196543
# 1237654028714901623 164.593078795242 ...   3.301496     0.6890357
# 1237651752929854191 164.640625102637 ...   1.457518     0.1937261
# 1237651752929854189 164.638880286984 ...   1.379502     0.2325576
# 1237651752929854186 164.633184946317 ...    1.76896       0.36334
#                 ...              ... ...        ...           ...
# 1237654029251772736 164.492627308242 ...   1.614829     0.3977808
# 1237654029251772737 164.493863304755 ...   1.811741     0.2921337
# 1237654029251772738 164.493087015177 ...   1.754216     0.4984101
# 1237654029251772744 164.498573488041 ...   1.895637     0.3128337
# 1237654029251772772 164.515878809692 ...   2.183008     0.5105629
# 1237654029251772781 164.522435789618 ...   4.102312     0.4359485
# 1237654029251772783 164.523321707259 ...   7.360025       -1000.0
# 1237654029251838235 164.689006173972 ...   2.475734     0.1605097
# 1237654029251838627 164.713555125471 ...   1.673918     0.2902485
# 1237654029251838648 164.749456085227 ...   1.018083      0.143828
